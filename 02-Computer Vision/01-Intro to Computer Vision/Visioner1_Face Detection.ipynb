# %% [markdown]
# ## Deskripsi
#
# Ini adalah program deteksi wajah sederhana berdasarkan Hands On yang telah diberikan.
# Dalam prosesnya kami mencoba untuk tidak hanya mendeteksi wajah tetapi juga mendeteksi mata dan senyuman dari gambar yang diinputkan.
#
# **Kelompok Visioner 1**
# 1. Angga Apriano Hermawan
# 2. Jeremyas Cornelis Abigail Wihardjono
# 3. Oktavandi Widhi Prakoso
# 4. Sandy Tirta Pratama

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('person2.png')

facecascade = cv2.CascadeClassifier('xml/haarcascade_frontalface_default.xml')
eyecascade = cv2.CascadeClassifier('xml/haarcascade_eye.xml')
smilecascade = cv2.CascadeClassifier('xml/haarcascade_smile.xml')

# plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Applying the face detection method on the grayscale image
faces_rect = facecascade.detectMultiScale(gray_img, scaleFactor=1.2, minNeighbors=5, minSize=(20,20))

# Iterating through rectangles of detected faces
for (x, y, w, h) in faces_rect:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    roi_gray = gray_img[y:y+h, x:x+w]
    eyes_rect = eyecascade.detectMultiScale(roi_gray, scaleFactor=1.2, minNeighbors=2)
    smiles_rect = smilecascade.detectMultiScale(roi_gray, scaleFactor=1.7, minNeighbors=3)
    
    for (ex, ey, ew, eh) in eyes_rect:
                
        cv2.rectangle(img[y:y+h, x:x+w], (ex, ey), (ex+ew, ey+eh), (255,0,0), 2)
    
    for (sx, sy, sw, sh) in smiles_rect:
        cv2.rectangle(img[y:y+h, x:x+w], (sx, sy), (sx+sw, sy+sh), (0,0,255), 2)
    
cv2.imshow('frame', img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# plt.imshow(img)

# %% [markdown]
# ## Penjelasan
#
# ![image.png](attachment:image.png)
#
# Seperti yang dapat dilihat pada screenshot gambar di atas.
# Warna Hijau untuk boundaries deteksi wajah
# Warna Biru untuk boundaries deteksi mata
# Warna Merah untuk boundaries deteksi senyum
#
# **Flow Kode** <br>
# Ide dasarnya adalah kami mendeteksi terlebih dahulu wajah nya, setelah didapati batas-batas wajah, maka kami menjadikan itu dasar untuk deteksi hal lain seperti mata dan senyum. Dan tentunya, memilih foto yang proper adalah hal yang penting.
